# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('_channel_lc1_raw.csv')

# %%
df.columns.values
# Out:
# array(['T[ms]', 'LC1[tick]'], dtype=object)

# %%
x = df['T[ms]'][:5000]
y = df['LC1[tick]'][:5000]
plt.plot(x,y)
plt.show()
